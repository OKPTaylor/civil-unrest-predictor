# %%
# mlp for regression
#import libraries for plotting the results
from numpy import mean
from numpy import std
from numpy import dstack
from pandas import read_csv
from matplotlib import pyplot

#import scikeras
#from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

from numpy import sqrt
from pandas import read_csv
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#lode csv and turn into dataframe
df = read_csv('civil_unrest_2021-08-04-2023-08-04.csv', header=0)

# %%
df.head()
# Out:
#   event_id_cnty    event_date  year  time_precision       disorder_type  \
# 0      ETH10298  28 July 2023  2023               1      Demonstrations
# 1      SAF19500  28 July 2023  2023               2      Demonstrations
# 2      SAF19506  28 July 2023  2023               1      Demonstrations
# 3      SAF19513  28 July 2023  2023               1      Demonstrations
# 4       SSD9374  28 July 2023  2023               2  Political violence
#
#                    event_type             sub_event_type  \
# 0                    Protests  Protest with intervention
# 1                    Protests           Peaceful protest
# 2                    Protests           Peaceful protest
# 3                       Riots      Violent demonstration
# 4  Violence against civilians                     Attack
#
#                                    actor1  \
# 0                   Protesters (Ethiopia)
# 1               Protesters (South Africa)
# 2               Protesters (South Africa)
# 3                  Rioters (South Africa)
# 4  Unidentified Armed Group (South Sudan)
#
#                                    assoc_actor_1  inter1  ...  \
# 0  Former TPLF: Tigray People's Liberation Front       6  ...
# 1                               Operation Dudula       6  ...
# 2                                            NaN       6  ...
# 3                                            NaN       5  ...
# 4                                            NaN       3  ...
#
#            location latitude  longitude  geo_precision  \
# 0            Mekele  13.5000    39.4667              1
# 1          Zwelihle -34.4311    19.2151              1
# 2            Durban -29.8579    31.0292              1
# 3  Pietermaritzburg -29.6167    30.3833              1
# 4             Liria   4.6437    32.0797              2
#
#                       source  source_scale  \
# 0               Addis Maleda      National
# 1  Daily News (South Africa)      National
# 2  Daily News (South Africa)      National
# 3     Citizen (South Africa)      National
# 4    Eye Radio (South Sudan)      National
#
#                                                notes fatalities  \
# 0  On 28 July 2023, over 6000 war injured former ...          0
# 1  Around 28 July 2023 (as reported), Hermanus re...          0
# 2  On 28 July 2023, dozens of utility ratepayers ...          0
# 3  On 28 July 2023, demonstrators barricaded Old ...          0
# 4  Around 28 July 2023 (as reported), the adminis...          0
#
#                    tags   timestamp
# 0  crowd size=over 6000  1690811106
# 1  crowd size=no report  1690811106
# 2     crowd size=dozens  1690811106
# 3  crowd size=no report  1690811106
# 4                   NaN  1690811106
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (378056, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378056 entries, 0 to 378055
# Data columns (total 31 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   event_id_cnty       378056 non-null  object
#  1   event_date          378056 non-null  object
#  2   year                378056 non-null  int64
#  3   time_precision      378056 non-null  int64
#  4   disorder_type       378056 non-null  object
#  5   event_type          378056 non-null  object
#  6   sub_event_type      378056 non-null  object
#  7   actor1              378056 non-null  object
#  8   assoc_actor_1       229866 non-null  object
#  9   inter1              378056 non-null  int64
#  10  actor2              103742 non-null  object
#  11  assoc_actor_2       42397 non-null   object
#  12  inter2              378056 non-null  int64
#  13  interaction         378056 non-null  int64
#  14  civilian_targeting  72810 non-null   object
#  15  iso                 378056 non-null  int64
#  16  region              378056 non-null  object
#  17  country             378056 non-null  object
#  18  admin1              378051 non-null  object
#  19  admin2              368315 non-null  object
#  20  admin3              156478 non-null  object
#  21  location            378056 non-null  object
#  22  latitude            378056 non-null  float64
#  23  longitude           378056 non-null  float64
#  24  geo_precision       378056 non-null  int64
#  25  source              378056 non-null  object
#  26  source_scale        378056 non-null  object
#  27  notes               378056 non-null  object
#  28  fatalities          378056 non-null  int64
#  29  tags                319074 non-null  object
#  30  timestamp           378056 non-null  int64
# dtypes: float64(2), int64(9), object(20)
# memory usage: 89.4+ MB
